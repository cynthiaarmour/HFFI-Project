# %%
import pandas as pd

# %%
df = pd.read_csv("releaseTLR_fy03_17(1of6).csv")

# %%
df.head(10)
# Out:
#    org_id  trans_id  originalamount projectfipscode_2000 projectfipscode_2010  \
# 0    2930         3            2500           9001045400                 NONE
# 1    2930         6           45888          23013970400                 NONE
# 2    2930         7          100000          23031030203                 NONE
# 3    2930         8          105000          23015975200                 NONE
# 4    2930         9          100000          23013970700                 NONE
# 5    2930        10          110000          23005001500                 NONE
# 6    2930        11          310225          23015975500                 NONE
# 7    2930        12           75000          23015975600                 NONE
# 8    2930        13          100000          23015975500                 NONE
# 9    2930        14           45000          23015975500                 NONE
#
#   investeetype dateclosed    purpose transactiontype  originalinterestrate  \
# ...

# %%
df.describe()
# Out:
#               org_id       trans_id  originalamount  originalinterestrate  \
# count  100871.000000  100871.000000    1.008710e+05          89957.000000
# mean     3291.056012   50116.843404    9.425307e+04              8.758180
# std       193.870057   28808.331764    4.477333e+05              4.073958
# min      2930.000000       3.000000    1.000000e+01              1.000000
# 25%      3165.000000   25169.500000    3.905000e+03              5.750000
# 50%      3344.000000   50337.000000    1.012200e+04              8.000000
# 75%      3444.000000   74764.500000    3.790600e+04             11.990000
# max      3703.000000   99999.000000    3.950000e+07             20.000000
#
#              points  originationfees  originalterm  valueofcollateral  \
# count  89837.000000     89352.000000  94458.000000       5.579500e+04
# mean       0.105530      1045.535427     91.564452       2.862928e+05
# std        0.424556      5374.054134    109.432141       9.956363e+05
# ...

# %%
df.originalamount.plot.hist()

# %%
df.loc[df.originalamount < 5000000].originalamount.plot.hist()

# %%
df.loc[df.originalamount < 1000000].originalamount.plot.hist(bins=10)

# %%
df.loc[df.originalamount < 100000].originalamount.plot.hist(bins=10)

# %%
hdf = pd.read_csv("DataDownload2.csv", encoding="ISO-8859-1")

# %%
hdf.head(10)
# Out:
#    FIPS State    County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0  1001    AL   Autauga                   11.4                   13.0
# 1  1003    AL   Baldwin                    9.8                   10.4
# 2  1005    AL   Barbour                   13.6                   18.4
# 3  1007    AL      Bibb                   11.1                   14.8
# 4  1009    AL    Blount                   11.4                   14.1
# 5  1011    AL   Bullock                   14.9                   19.6
# 6  1013    AL    Butler                   15.1                   17.7
# 7  1015    AL   Calhoun                   14.5                   14.9
# 8  1017    AL  Chambers                   16.1                   16.4
# 9  1019    AL  Cherokee                   13.6                   13.3
#
#    PCT_OBESE_ADULTS08  PCT_OBESE_ADULTS13  PCT_HSPA15  RECFAC09  RECFAC14  \
# 0                31.5                34.1        25.4         4         5
# ...
